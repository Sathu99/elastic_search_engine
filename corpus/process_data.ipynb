# %%
import pandas as pd

# %%
data = pd.read_csv("Tamil A.R Rahman Melody Songs Lyrics.csv")
data
# Out:
#                           பாடல்              படம்  வருடம்  இசையமைப்பாளர்  \
# 0           ராஜ்யமா இல்லை இமயமா              பாபா    2002     AR ரஹ்மான்
# 1                  அஞ்சாதே ஜீவா              ஜோடி    1999     AR ரஹ்மான்
# 2     ஒரு பொய்யாவது  சொல் கண்ணே              ஜோடி    1999     AR ரஹ்மான்
# 3                 சோனியா சோனியா           ரட்சகன்    1997     AR ரஹ்மான்
# 4      நெஞ்சே நெஞ்சே மறந்துவிடு           ரட்சகன்    1997     AR ரஹ்மான்
# ..                          ...               ...     ...            ...
# 106       நான் முத்தம் தின்பவள்              குரு    2007  ஏ.ஆர்.ரஹ்மான்
# 107                       மாதரே            பிகில்    2019  ஏ.ஆர்.ரஹ்மான்
# 108              ஆத்தங்கரை மரமே  கிழக்கு சீமையிலே    1993  ஏ.ஆர்.ரகுமான்
# 109     உனக்காக வாழ நெனைக்கறேன்            பிகில்    2019  ஏ.ஆர்.ரகுமான்
# 110  பூக்களே சற்று ஓய்வெடுங்கள்                 ஐ    2015  ஏ.ஆர்.ரஹ்மான்
#
#                                           பாடல் வரிகள்  \
# ...

# %%
data['பாடல்வரிகள்'] = data['பாடல் வரிகள்']
data = data.drop('பாடல் வரிகள்', axis=1)
data
# Out:
#                           பாடல்              படம்  வருடம்  இசையமைப்பாளர்  \
# 0           ராஜ்யமா இல்லை இமயமா              பாபா    2002     AR ரஹ்மான்
# 1                  அஞ்சாதே ஜீவா              ஜோடி    1999     AR ரஹ்மான்
# 2     ஒரு பொய்யாவது  சொல் கண்ணே              ஜோடி    1999     AR ரஹ்மான்
# 3                 சோனியா சோனியா           ரட்சகன்    1997     AR ரஹ்மான்
# 4      நெஞ்சே நெஞ்சே மறந்துவிடு           ரட்சகன்    1997     AR ரஹ்மான்
# ..                          ...               ...     ...            ...
# 106       நான் முத்தம் தின்பவள்              குரு    2007  ஏ.ஆர்.ரஹ்மான்
# 107                       மாதரே            பிகில்    2019  ஏ.ஆர்.ரஹ்மான்
# 108              ஆத்தங்கரை மரமே  கிழக்கு சீமையிலே    1993  ஏ.ஆர்.ரகுமான்
# 109     உனக்காக வாழ நெனைக்கறேன்            பிகில்    2019  ஏ.ஆர்.ரகுமான்
# 110  பூக்களே சற்று ஓய்வெடுங்கள்                 ஐ    2015  ஏ.ஆர்.ரஹ்மான்
#
#                                              பாடகர்கள்   பாடலாசிரியர்  \
# ...

# %%
data.isnull().sum()
# Out:
# பாடல்            0
# படம்             0
# வருடம்           0
# இசையமைப்பாளர்    0
# பாடகர்கள்        0
# பாடலாசிரியர்     0
# உருவகம்          0
# உவமானம்          0
# உவமேயம்          0
# பாடல்வரிகள்      0
# dtype: int64

# %%
data.to_json('Tamil A.R Rahman Melody Songs Lyrics.json', orient='records', lines=True, force_ascii=False)
